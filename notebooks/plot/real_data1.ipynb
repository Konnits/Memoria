# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv("../../data/processed/real_data_1.csv", parse_dates=["timestamp"])

# %%
# Hacemos que sea de tipo scatter
df.iloc[-1000:]["valor"].plot(figsize=(15, 5), marker='o', markersize=1)
